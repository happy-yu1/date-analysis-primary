# %%
pip install tushare
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/bf/3f/149ef2a80cddd24410e6788228a22f3b3afb5c55c765a223a5c7ecf93ecf/tushare-1.2.48-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tushare as ts

# %% [markdown]
# ### 1、初始化

# %%
pro=ts.pro_api('5f2dc9d17ebed3601a4fbea74148a25067d067138bf88515693e9b7d')

# %% [markdown]
# ### 2、提取详情

# %%
df=pro.stock_basic(exchange='SSE',list_status='L', fields='ts_code,symbol,name,area,industry,list_date')
df
# Out:
#         ts_code  symbol  name area industry list_date
# 0     600000.SH  600000  浦发银行   上海       银行  19991110
# 1     600004.SH  600004  白云机场   广东       机场  20030428
# 2     600006.SH  600006  东风汽车   湖北     汽车整车  19990727
# 3     600007.SH  600007  中国国贸   北京     园区开发  19990312
# 4     600008.SH  600008  首创股份   北京     环境保护  20000427
# 5     600009.SH  600009  上海机场   上海       机场  19980218
# 6     600010.SH  600010  包钢股份   内蒙       普钢  20010309
# 7     600011.SH  600011  华能国际   北京     火力发电  20011206
# 8     600012.SH  600012  皖通高速   安徽       路桥  20030107
# 9     600015.SH  600015  华夏银行   北京       银行  20030912
# 10    600016.SH  600016  民生银行   北京       银行  20001219
# 11    600017.SH  600017   日照港   山东       港口  20061017
# 12    600018.SH  600018  上港集团   上海       港口  20061026
# 13    600019.SH  600019  宝钢股份   上海       普钢  20001212
# 14    600020.SH  600020  中原高速   河南       路桥  20030808
# 15    600021.SH  600021  上海电力   上海     火力发电  20031029
# ...

# %%
df=pro.stock_basic(exchange='SZSE',list_status='L', fields='ts_code,symbol,name,area,industry,market,list_date')
df
# Out:
#         ts_code  symbol   name  area industry market list_date
# 0     000001.SZ  000001   平安银行    深圳       银行     主板  19910403
# 1     000002.SZ  000002    万科A    深圳     全国地产     主板  19910129
# 2     000004.SZ  000004   国农科技    深圳     生物制药     主板  19910114
# 3     000005.SZ  000005   世纪星源    深圳     环境保护     主板  19901210
# 4     000006.SZ  000006   深振业A    深圳     区域地产     主板  19920427
# 5     000007.SZ  000007    全新好    深圳     酒店餐饮     主板  19920413
# 6     000008.SZ  000008   神州高铁    北京     运输设备     主板  19920507
# 7     000009.SZ  000009   中国宝安    深圳      综合类     主板  19910625
# 8     000010.SZ  000010  *ST美丽    深圳     建筑工程     主板  19951027
# 9     000011.SZ  000011   深物业A    深圳     区域地产     主板  19920330
# 10    000012.SZ  000012    南玻A    深圳       玻璃     主板  19920228
# 11    000014.SZ  000014   沙河股份    深圳     全国地产     主板  19920602
# 12    000016.SZ  000016   深康佳A    深圳     家用电器     主板  19920327
# 13    000017.SZ  000017   深中华A    深圳     文教休闲     主板  19920331
# ...

# %% [markdown]
# #### 提取指数行情---代码为'399300.SZ'的指数，从20190101 到 20191010期间的行情信息，包括：开盘价、收盘价、最高、最低、change（涨跌点），pct_chg（涨跌幅），amount（成交额），vol（成交手），pre_close	（昨日收盘价）

# %%
df = pro.index_daily(ts_code='399300.SZ', start_date='20190101', end_date='20191010')
df.head(10)  #只显示前10行的信息，若不填则默认显示5行
# Out:
#      ts_code trade_date      close       open       high        low  \
# 0  399300.SZ   20191010  3874.6391  3838.4865  3877.1420  3829.4328
# 1  399300.SZ   20191009  3843.2392  3822.6068  3845.3403  3805.0671
# 2  399300.SZ   20191008  3837.6791  3818.5894  3861.6429  3818.5894
# 3  399300.SZ   20190930  3814.5282  3842.0741  3857.2319  3813.5491
# 4  399300.SZ   20190927  3852.6534  3843.4584  3859.5003  3832.2466
# 5  399300.SZ   20190926  3841.1388  3884.7022  3890.7452  3840.2472
# 6  399300.SZ   20190925  3870.9837  3887.5548  3889.8390  3867.2277
# 7  399300.SZ   20190924  3901.0758  3895.8661  3927.0115  3886.1404
# 8  399300.SZ   20190923  3890.6616  3925.1858  3925.1858  3868.2140
# 9  399300.SZ   20190920  3935.6511  3933.4594  3942.2240  3921.4124
#
#    pre_close   change  pct_chg          vol       amount
# 0  3843.2392  31.3999   0.8170   79222694.0  127474042.8
# 1  3837.6791   5.5601   0.1449   75854512.0  112406207.0
# ...
