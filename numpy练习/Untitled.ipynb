# 48    27.79    16.09  26.32  3.27  2.44     3.98
# 49    26.90    14.07  23.98  3.29  2.45     4.08
# 50    25.26    12.80  22.03  3.29  2.46     4.18
# 51    24.89    12.82  21.48  3.27  2.45     3.97
# 52    27.09    14.10  22.81  3.29  2.43     4.02
# 53    28.44    14.61  23.43  3.30  2.45     4.13
# 54    29.71    15.70  24.72  3.32  2.48     3.95
# 55    29.87    16.04  25.39  3.35  2.49     4.03
# 56    28.30    15.86  25.24  3.37  2.49     4.38
# 57    26.43    15.77  25.07  3.36  2.46     4.47

# %%
train_x.shape
# Out:
# (58, 6)

# %%
train_y = pd.read_csv("trainy.csv")
train_y
# Out:
#     hog inventory
# 0          456.16
# 1          445.94
# 2          448.61
# 3          454.89
# 4          453.25
# 5          447.20
# 6          450.06
# 7          458.16
# 8          465.16
# 9          469.21
# 10         465.90
# 11         469.00
# 12         455.00
# 13         443.30
# 14         441.30
# 15         436.00
# 16         433.70
# 17         436.70
# 18         440.00
# 19         441.80
# 20         454.50
# 21         454.40
# 22         454.70
# 23         453.80
# 24         445.10
# 25         444.10
# 26         447.50
# 27         449.20
# 28         452.80
# 29         456.40
# 30         461.42
# 31         465.57
# 32         471.58
# 33         475.16
# 34         476.25
# 35         473.34
# 36         464.67
# 37         458.46
# 38         461.67
# 39         463.06
# 40         461.21
# 41         462.13
# 42         462.13
# 43         466.29
# 44         472.35
# 45         472.82
# 46         469.04
# 47         462.94
# 48         448.13
# 49         439.62
# 50         443.58
# 51         446.69
# 52         447.58
# 53         452.06
# 54         457.48
# 55         461.60
# 56         464.83
# 57         467.62

# %%
train_y.shape
# Out:
# (58, 1)

# %%
train_y=np.loadtxt('trainy.csv',skiprows=1)
train_y
# Out:
# array([456.16, 445.94, 448.61, 454.89, 453.25, 447.2 , 450.06, 458.16,
#        465.16, 469.21, 465.9 , 469.  , 455.  , 443.3 , 441.3 , 436.  ,
#        433.7 , 436.7 , 440.  , 441.8 , 454.5 , 454.4 , 454.7 , 453.8 ,
#        445.1 , 444.1 , 447.5 , 449.2 , 452.8 , 456.4 , 461.42, 465.57,
#        471.58, 475.16, 476.25, 473.34, 464.67, 458.46, 461.67, 463.06,
#        461.21, 462.13, 462.13, 466.29, 472.35, 472.82, 469.04, 462.94,
#        448.13, 439.62, 443.58, 446.69, 447.58, 452.06, 457.48, 461.6 ,
#        464.83, 467.62])

# %%
train_y.shape
# Out:
# (58,)

# %%
reg = RandomForestRegressor(max_depth=2, random_state=1, n_estimators=100)

# %%
reg.fit(train_x,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=2,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=100,
#                       n_jobs=None, oob_score=False, random_state=1, verbose=0,
#                       warm_start=False)
