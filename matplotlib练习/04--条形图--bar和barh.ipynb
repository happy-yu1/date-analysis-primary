# %% [markdown]
# ### 以“电影票房”网站为例，作出不同电影的票房大小比较

# %%
from  matplotlib import pyplot as plt
import  random
from matplotlib import font_manager

x = ["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5：最后的骑士","摔跤吧！爸爸","加勒比海盗5：死无对证","金刚：骷髅岛","极限特工：终极回归","生化危机6：终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3：殊死一战","蜘蛛侠：英雄归来","悟空传","银河护卫队2","情圣","新木乃伊",]

y=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

# %% [markdown]
# #### 1、做出简单草图--按以前的操作，传入x，y----x轴的信息有中文不显示

# %%
plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(x,y,width=0.4)

plt.show()

# %% [markdown]
# #### 2、做出简单草图--bar（）传入的参数必须是可遍历的数字类型的数据，要将x信息转化成数据类型

# %%
plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(range(len(x)),y,width=0.4)

plt.show()

# %% [markdown]
# #### 3、修改x刻度,并传入中文字体

# %%
plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(range(len(x)),y,width=0.4)
plt.xticks(range(len(x)),x,fontproperties=my_font)

plt.show()

# %% [markdown]
# #### 4、添加标签

# %%
plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(range(len(x)),y,width=0.4)
plt.xticks(range(len(x)),x,fontproperties=my_font,rotation=45)  


plt.xlabel('电影名称',fontproperties=my_font)
plt.ylabel('票房',fontproperties=my_font)
plt.title('电影票房对比条形图',fontproperties=my_font)

plt.show()

# %% [markdown]
# #### 5、图片完善
# #### 以上操作，因电影名字太长，名字和刻度出现对应偏差问题，需要进行美化

# %% [markdown]
# #### 5.1、电影名字竖着排列

# %%
plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(range(len(x)),y,width=0.4)
plt.xticks(range(len(x)),x,fontproperties=my_font,rotation=90)  


plt.xlabel('电影名称',fontproperties=my_font)
plt.ylabel('票房',fontproperties=my_font)
plt.title('电影票房对比条形图',fontproperties=my_font)

plt.show()

# %% [markdown]
# #### 5.2、将电影名字较长的，进行换行处理----\n

# %%
x = ["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5：\n最后的骑士","摔跤吧！爸爸","加勒比海盗5：\n死无对证","金刚：骷髅岛","极限特工：\n终极回归","生化危机6：终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3：\n殊死一战","蜘蛛侠：\n英雄归来","悟空传","银河护卫队2","情圣","新木乃伊",]

plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(range(len(x)),y,width=0.4)
plt.xticks(range(len(x)),x,fontproperties=my_font,rotation=90)  


plt.xlabel('电影名称',fontproperties=my_font)
plt.ylabel('票房',fontproperties=my_font)
plt.title('电影票房对比条形图',fontproperties=my_font)

plt.show()

# %% [markdown]
# #### 5.3、将电影信息放在y轴上展示---barh（）横条形图

# %%
plt.figure(figsize=(20,9),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')

plt.barh(range(len(x)),y,height=0.6)   #bar----barh,width---height
plt.yticks(range(len(x)),x,fontproperties=my_font)   #xticks----yticks


plt.ylabel('电影名称',fontproperties=my_font)
plt.xlabel('票房',fontproperties=my_font)
plt.title('电影票房对比条形图',fontproperties=my_font)

plt.show()

# %% [markdown]
# #### 5.2、将电影信息放在y轴上展示--直接将x，y轴替换呢？  (不可以，只能用barh（）横条形图

# %%
# x = ["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5：最后的骑士","摔跤吧！爸爸","加勒比海盗5：死无对证","金刚：骷髅岛","极限特工：终极回归","生化危机6：终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3：殊死一战","蜘蛛侠：英雄归来","悟空传","银河护卫队2","情圣","新木乃伊",]

# y=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]


y = ["战狼2","速度与激情8","功夫瑜伽","西游伏妖篇","变形金刚5：最后的骑士","摔跤吧！爸爸","加勒比海盗5：死无对证","金刚：骷髅岛","极限特工：终极回归","生化危机6：终章","乘风破浪","神偷奶爸3","智取威虎山","大闹天竺","金刚狼3：殊死一战","蜘蛛侠：英雄归来","悟空传","银河护卫队2","情圣","新木乃伊",]
x=[56.01,26.94,17.53,16.49,15.45,12.96,11.8,11.61,11.28,11.12,10.49,10.3,8.75,7.55,7.32,6.99,6.88,6.86,6.58,6.23]

plt.figure(figsize=(20,8),dpi=90)
my_font=font_manager.FontProperties(fname='C:/Windows/Fonts/simsun.ttc')
plt.bar(x,range(len(y)),width=0.4)
plt.yticks(range(len(y)),y,fontproperties=my_font)  


plt.ylabel('电影名称',fontproperties=my_font)
plt.xlabel('票房',fontproperties=my_font)
plt.title('电影票房对比条形图',fontproperties=my_font)

plt.show()
